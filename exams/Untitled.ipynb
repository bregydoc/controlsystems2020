# %%
import control as ct
import control2020 as ct20
import numpy as np
import sympy as sp
from matplotlib import pyplot as plt


s = sp.var("s") # symbolic variable to represent the laplace space

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
G = (s + 2) / (s**5 + 2*s**4 + 3*s**3 + 1*s**2 - 1.5*s + 1) 
G = ct20.core.symbolic_transfer_function(G)

# %%
ct.nyquist(G)
# Out:
# (array([1.99959974e+00, 1.99941691e+00, 1.99915045e+00, 1.99876198e+00,
#         1.99819537e+00, 1.99736834e+00, 1.99616000e+00, 1.99439198e+00,
#         1.99179967e+00, 1.98798753e+00, 1.98235815e+00, 1.97399706e+00,
#         1.96148091e+00, 1.94255142e+00, 1.91355613e+00, 1.86850419e+00,
#         1.79758463e+00, 1.68532788e+00, 1.51013938e+00, 1.25108110e+00,
#         9.11163074e-01, 5.47615567e-01, 2.54746146e-01, 8.76445916e-02,
#         3.11579573e-02, 4.20896391e-02, 8.20304589e-02, 1.08416938e-01,
#         8.62427274e-02, 4.64495512e-02, 2.12905142e-02, 9.41596847e-03,
#         4.18248385e-03, 1.88188854e-03, 8.57268066e-04, 3.94369684e-04,
#         1.82748972e-04, 8.51295393e-05, 3.98026117e-05, 1.86580254e-05,
#         8.76193406e-06, 4.11978215e-06, 1.93874759e-06, 9.12904113e-07,
#         4.30037047e-07, 2.02632074e-07, 9.54979637e-08, 4.50129506e-08,
#         2.12187756e-08, 1.00030000e-08]),
# ...
